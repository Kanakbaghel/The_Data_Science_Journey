# %% [markdown]
# # Solutions

# %% [markdown]
# ## Normal Distribution

# %%
import scipy.stats as stats
from math import sqrt
import pandas as pd

# %% [raw]
# 1.	The average stock price for companies making up the S&P 500 is $30, and the standard deviation is $8.20 (BusinessWeek, Special Annual Issue, Spring 2003). Assume the stock prices are normally distributed.
# a.	What is the probability a company will have a stock price of at least $40?
# b.	What is the probability a company will have a stock price no higher than $20?
# c.	How high does a stock price have to be to put a company in the top 10%?

# %%
# pop_mean
mu = 30
# pop std 
sigma = 8.20

# %% [markdown]
# #### a. What is the probability a company will have a stock price of at least $40?

# %%
# > 40 right tail
x = 40

# %%
1 - stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.11132492503925329

# %% [markdown]
# #### b.	What is the probability a company will have a stock price no higher than $20?

# %%
# < 20 left tail
x = 20

# %%
stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.11132492503925329

# %% [markdown]
# #### c. How high does a stock price have to be to put a company in the top 10%?

# %%
# top 10 % means right side area = 10% left area = 100 - 10 = 90
p = 0.9

# %%
stats.norm.ppf(p, loc = mu, scale = sigma)
# Out:
# 40.508722837465726

# %% [raw]
# 2.	In an article about the cost of health care, Money magazine reported that a visit to a hospital emergency room for something as simple as a sore throat has a mean cost of $328 (Money, January 2009). Assume that the cost for this type of hospital emergency room visit is normally distributed with a standard deviation of $92. Answer the following questions about the cost of a hospital emergency room visit for this medical service.

# %%
# pop_mean
mu = 328
# pop std 
sigma = 92

# %% [markdown]
# #### a.	What is the probability that the cost will be more than $500?

# %%
x = 500
# > 500 right tail
1 - stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.030772109600403552

# %% [markdown]
# #### b.	What is the probability that the cost will be less than $250?

# %%
x = 250
# < 250 left tail
stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.19826741629443773

# %% [markdown]
# #### c.	What is the probability that the cost will be between $300 and $400?

# %%
x1 = 300
x2 = 400
# between 300 & 400
stats.norm.cdf(x2, loc = mu, scale = sigma)-  stats.norm.cdf(x1, loc = mu, scale = sigma)
# Out:
# 0.4026400771146216

# %% [markdown]
# #### d.	If the cost to a patient is in the lower 8% of charges for this medical service, what was the cost of this patient’s emergency room visit

# %%
p = 0.08

# %%
stats.norm.ppf(p, loc = mu, scale = sigma)
# Out:
# 198.7334164515138

# %% [raw]
# 3.	In January 2003, the American worker spent an average of 77 hours logged on to the Internet while at work (CNBC, March 15, 2003). Assume the population mean is 77 hours, the times are normally distributed, and that the standard deviation is 20 hours.

# %%
# pop_mean
mu = 77
# pop std 
sigma = 20

# %% [markdown]
# #### a.	What is the probability that in January 2003 a randomly selected worker spent fewer than 50 hours logged on to the Internet?

# %%
x = 50
# < 50 left 
stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.08850799143740196

# %% [markdown]
# #### b.	What percentage of workers spent more than 100 hours in January 2003 logged on to the Internet?

# %%
x = 100
# > 100 right
(1 - stats.norm.cdf(x, loc = mu, scale = sigma) )* 100 # percentage
# Out:
# 12.507193563715035

# %% [markdown]
# #### c.	A person is classified as a heavy user if he or she is in the upper 20% of usage. In January 2003, how many hours did a worker have to be logged on to the Internet to be considered a heavy user?

# %%
# upper 20% --> 80th percentile
p = 0.8
stats.norm.ppf(p, loc = mu, scale = sigma)
# Out:
# 112.62431850359371

# %% [raw]
# 4.	A person must score in the upper 2% of the population on an IQ test to qualify for membership in Mensa, the international high-IQ society (U.S. Airways Attaché, September 2000). If IQ scores are normally distributed with a mean of 100 and a standard deviation of 15, what score must a person have to qualify for Mensa?

# %%
# pop_mean
mu = 100
# pop std 
sigma = 15

# %%
# uppeer 2 % i.e 98% from left
p = 0.98
stats.norm.ppf(p, loc= mu, scale = sigma)
# Out:
# 2.0537489106318225

# %% [raw]
# 5.	The mean hourly pay rate for financial managers in the East North Central region is $32.62,  and the standard deviation is $2.32 (Bureau of Labor Statistics, September 2005). Assume that pay rates are normally distributed.

# %%
# pop_mean
mu = 32.62
# pop std 
sigma = 2.32

# %% [markdown]
# #### a.	What is the probability a financial manager earns between $30 and $35 per hour?

# %%
# between 30 & 35
x1 =30
x2 = 35
stats.norm.cdf(x2, loc = mu, scale = sigma)-  stats.norm.cdf(x1, loc = mu, scale = sigma)
# Out:
# 0.7181382287167163

# %% [markdown]
# #### b.	How high must the hourly rate be to put a financial manager in the top 10% with respect to pay?

# %%
# top 10 % i.e 90% from left
p = 0.90
stats.norm.ppf(p, loc= mu, scale = sigma)
# Out:
# 35.593199632063474

# %% [markdown]
# #### c.	For a randomly selected financial manager, what is the probability the manager earned less than $28 per hour?

# %%
# < 28 left
x = 28
stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.023219601042608874

# %% [raw]
# 6.	The time needed to complete a final examination in a particular college course is normally distributed with a mean of 80 minutes and a standard deviation of 10 minutes. Answer the following questions.

# %%
# pop_mean
mu = 80
# pop std 
sigma = 10

# %% [markdown]
# #### a.	What is the probability of completing the exam in one hour or less?

# %%
# 1 hour or less < 60 | left
x = 60
stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.022750131948179195

# %% [markdown]
# #### b.	What is the probability that a student will complete the exam in more than 60 minutes but less than 75 minutes?

# %%
# between 60 & 75
x1 =60
x2 = 75
stats.norm.cdf(x2, loc = mu, scale = sigma)-  stats.norm.cdf(x1, loc = mu, scale = sigma)
# Out:
# 0.2857874067778077

# %% [markdown]
# #### c.	Assume that the class has 60 students and that the examination period is 90 minutes in length. How many students do you expect will be unable to complete the exam in the allotted time?

# %%
# prob that students will take more than 90 mins to complete the test | > 90 | right
x = 90
p = stats.norm.cdf(x, loc = mu, scale = sigma)

# prob of students requiring < 90 mins 

# no. of students 
tot_students = 60 

# no. of studnets able to complete the test

60 - int((60*p))
# Out:
# 10

# %% [raw]
# 7.	Trading volume on the New York Stock Exchange is heaviest during the first half hour (early morning) and last half hour (late afternoon) of the trading day. The early morning trading volumes (millions of shares) for 13 days in January and February are shown here (Barron’s, January 23, 2006; February 13, 2006; and February 27, 2006).
# 214, 163, 265, 194, 180, 202, 198, 212, 201, 174, 171, 211, 211
# The probability distribution of trading volume is approximately normal.

# %%
data = pd.Series((214, 163, 265, 194, 180, 202, 198, 212, 201, 174, 171, 211, 211))

# %% [markdown]
# #### a.	Compute the mean and standard deviation to use as estimates of the population mean and standard deviation.

# %%
# mean
data.mean()
# Out:
# 199.69230769230768

# %%
# standard deviation
data.std()
# Out:
# 26.039664025561134

# %%
mean = data.mean()
std = data.std()

# %% [markdown]
# #### b.	What is the probability that, on a randomly selected day, the early morning trading volume will be less than 180 million shares?

# %%
# < 180 million shares | left

x = 180
stats.norm.cdf(x, loc = mean, scale = std)
# Out:
# 0.2247518264924484

# %% [markdown]
# #### c.	What is the probability that, on a randomly selected day, the early morning trading volume will exceed 230 million shares?

# %%
# > 230 million shares | left

x = 230
1 - stats.norm.cdf(x, loc = mean, scale = std)
# Out:
# 0.12223127873139361

# %% [markdown]
# #### d.	How many shares would have to be traded for the early morning trading volume on a particular day to be among the busiest 5% of days?

# %%
# top  5 % i.e 95% from left
p = 0.95
stats.norm.ppf(p, loc = mean, scale = std)
# Out:
# 242.52374350934969

# %% [raw]
# 8.	According to the Sleep Foundation, the average night’s sleep is 6.8 hours (Fortune, March 20, 2006). Assume the standard deviation is .6 hours and that the probability distribution is normal.

# %%
mu = 6.8
sigma = 0.6

# %% [markdown]
# #### a.	What is the probability that a randomly selected person sleeps more than 8 hours?

# %%
# > 8 hrs | right tail
x = 8
1 - stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.02275013194817921

# %% [markdown]
# #### b.	What is the probability that a randomly selected person sleeps 6 hours or less?

# %%
# < 6 hrs | left 
x = 6
stats.norm.cdf(x, loc = mu, scale = sigma)
# Out:
# 0.09121121972586793

# %% [markdown]
# #### c.	Doctors suggest getting between 7 and 9 hours of sleep each night. What percentage of the population gets this much sleep?

# %%
# between 7-8 hrs 
x1 = 7 
x2 = 8
stats.norm.cdf(x2, loc = mu, scale = sigma) - stats.norm.cdf(x1, loc = mu, scale = sigma)
# Out:
# 0.34669120823358435
